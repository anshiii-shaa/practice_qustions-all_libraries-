# %%
import numpy as np

# %%
# 1. Create a ufunc that takes two arrays and returns the modulus (remainder) of division for each element.

a=np.array([6,7,8,9,10])
b=np.array([1,2,3,4,5])
c=np.remainder(a,b)

print(c)
# Out:
# [0 1 2 1 0]

# %%
# 2. Define a ufunc that computes the cube of each element from two input arrays and then sums them.

# %%
# 3. Write a program to create a ufunc that checks if the elements of two arrays are equal. Test it with sample arrays.

# %% [markdown]
# Create Your Own ufunc

# %%
# 4. Create a ufunc that takes two arrays and returns the maximum of the two values for each element.

# %%
# 5. Write a ufunc to compute the power of elements in two arrays, where each element of one array is raised to the corresponding element of another array.

# %%
# 6. Implement a ufunc that takes an array and computes (x^3 - 2x^2 + x) for each element.

# %% [markdown]
# Simple Arithmetic with NumPy

# %%
# 7. Perform element-wise addition, subtraction, multiplication, and division on two 3x3 matrices using NumPy.

# %%
# 8. Create two arrays A = [1, 2, 3, 4] and B = [5, 6, 7, 8]. Perform element-wise power (A**B) and modulo (A % B).

# %%
# 9. Create two random arrays and compute their element-wise product and then sum the result using NumPy.
