# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Visualization of Class Imbalance
# 1. Dataset: Use the Iris dataset.
# • Visualize the class distribution of the target variable. Identify if there is any
# imbalance among the classes.

# %%
df=sns.load_dataset("iris")
sns.countplot(x=df["species"])
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# 2. Dataset: Titanic dataset.
# • Visualize the survival rates (Survived column) to determine if the dataset is
# imbalanced.

# %%
df=sns.load_dataset("titanic")

sns.countplot(x=df["survived"])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# 3. Dataset: Any fraud detection dataset.
# • Create a bar chart or pie chart to showcase the distribution between fraudulent and
# non-fraudulent cases.

# %%
df=pd.read_csv("/content/increased_transaction_dataset.csv")
df
# Out:
#        Unnamed: 0         FLAG  Avg min between sent tnx  \
# 0               0        Fraud                      0.00
# 1               1  Non - Fraud                 202252.36
# 2               2  Non - Fraud                  20807.97
# 3               3  Non - Fraud                     80.96
# 4               4        Fraud                      0.00
# ...           ...          ...                       ...
# 19677       19677  Non - Fraud                      0.00
# 19678       19678  Non - Fraud                      0.00
# 19679       19679  Non - Fraud                    149.14
# 19680       19680  Non - Fraud                   3208.85
# 19681       19681  Non - Fraud                  46276.85
#
#        Avg min between received tnx  Time Diff between first and last (Mins)  \
# 0                      34682.010000                             1.734100e+05
# 1                      13562.510000                             4.858798e+05
# ...

# %%
sns.barplot(x=df["FLAG"].value_counts().index,y=df["FLAG"].value_counts().values)
# Out:
# <Axes: xlabel='FLAG'>
