# %% [markdown]
# **Different type plots in matplolib?**
#
# ---
#
# - 1- line plot
# - 2- box plot
# - 3- pie plot
# - 4- histplot
# - 5- Scatter plot
# - 6- bar plot
# - 7- heatmap
# - 8- Violin plot
# - 9- Area plot
# - 10- Steam plot
# - 11- 3D plot

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
x=np.array([1,2])

plt.plot(x,c="r")
plt.plot(y,c="g")
plt.xlabel("X-label",c="m")
plt.ylabel("Y-label",c="g")
plt.title("yes",c="k",loc="left")
plt.show()

# %% [markdown]
# **Changing line style**
#
# ---
#
# into "dashed" and "doted"

# %%
x=np.array([1,2])
y=np.array([2,4])

plt.plot(x,c="r",linestyle="--")
plt.plot(y,c="g",linestyle=":")

plt.xlabel("X-label",c="m")
plt.ylabel("Y-label",c="y")

plt.title("yes",c="k")


plt.show()
